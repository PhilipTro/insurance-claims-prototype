# %%
import os
from pathlib import Path
import sys
PROJECT_ROOT = Path.home() / "Desktop" / "Insurance_Project" / "prototype"
os.chdir(PROJECT_ROOT)

print(os.getcwd())
# Out:
# C:\Users\phili\Desktop\Insurance_Project\prototype

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from src.models import classification as clf

# %%
import importlib
importlib.reload(clf)
X_train, X_test, y_train, y_test = clf.load_data() # type: ignore

# %%
X_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.387003  1.245954 -1.024560 -0.231305  1.393008  1.680462 -0.448411
# 1 -0.073645 -0.319877  1.414868  0.356974 -0.454075  1.569884  1.345233
# 2 -1.744205 -1.102792 -1.024560  0.499030  1.854779 -0.936787  0.448411
# 3  0.748516  0.686729  1.414868 -0.139506 -0.454075 -0.471977 -0.448411
# 4  0.005073  0.127503  1.414868  2.031566 -0.454075 -0.655679 -0.448411
#
#           7         8         9        10        11        12        13  \
# 0 -1.705965  1.275659  0.097496 -1.061913 -0.979414 -0.130189 -0.141605
# 1  0.288668  0.060746 -1.147138  0.941697 -0.979414 -0.130189  1.458728
# 2  0.454887  1.275659  0.097496 -1.061913 -0.294509 -0.130189  0.003880
# 3  0.122448 -1.154168  0.097496  0.941697  0.390396 -0.130189 -1.887423
# 4 -1.373527 -1.154168  0.097496 -1.061913  1.075300 -0.130189  1.458728
#
#          14        15        16   17        18        19
# 0 -0.309494  0.726371  0.245279  0.0 -0.694633  0.204597
# 1 -0.309494  0.726371  0.133788  0.0  0.107638 -0.832210
# 2  0.315746  0.726371  0.133788  0.0 -0.494065  1.863488
# 3 -0.309494  0.288456 -0.312173  0.0 -1.697472 -1.869017
# 4  0.211540  0.726371  1.137201  0.0 -0.494065  0.204597

# %%
models = clf.train_classifier(X_train, y_train)
# Out:
# training RandomForest...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# training XGBoost...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits

# %%
results = clf.evaluate_classifer(X_test, y_test, models)

# %%
print(results)
# Out:
# {'RandomForest': {'roc_auc': 0.47037109375, 'f1_score': 0.023255813953488372, 'classification_report': '              precision    recall  f1-score   support\n\n           0       0.80      0.98      0.88       320\n           1       0.17      0.01      0.02        80\n\n    accuracy                           0.79       400\n   macro avg       0.48      0.50      0.45       400\nweighted avg       0.67      0.79      0.71       400\n', 'confusion_matrix': array([[315,   5],
#        [ 79,   1]])}, 'XGBoost': {'roc_auc': 0.5067187500000001, 'f1_score': 0.1, 'classification_report': '              precision    recall  f1-score   support\n\n           0       0.80      0.95      0.87       320\n           1       0.25      0.06      0.10        80\n\n    accuracy                           0.78       400\n   macro avg       0.53      0.51      0.49       400\nweighted avg       0.69      0.78      0.72       400\n', 'confusion_matrix': array([[305,  15],
#        [ 75,   5]])}}

# %%
importlib.reload(clf)
# Out:
# <module 'src.models.classification' from 'C:\\Users\\phili\\Desktop\\Insurance_Project\\prototype\\src\\models\\classification.py'>

# %%
metric_string=""
for model, dict in results.items():
    metric_string += f"""
    -----METRICS FOR {model}------
    ROC_AUC: {dict['roc_auc']:.2f}
    F1_SCORE: {dict['f1_score']:.2f}
    \n
    
\tCLASSIFICATION REPORT\t
{dict['classification_report']}

\n
CONFUSION MATRIX FOR {model}
{dict['confusion_matrix']}
"""

# %%
print(metric_string)
# Out:
#     -----METRICS FOR RandomForest------
#     ROC_AUC: 0.47
#     F1_SCORE: 0.02
#
#
#
# 	CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88       320
#            1       0.17      0.01      0.02        80
#
#     accuracy                           0.79       400
#    macro avg       0.48      0.50      0.45       400
# weighted avg       0.67      0.79      0.71       400
#
#
#
#
# CONFUSION MATRIX FOR RandomForest
# [[315   5]
#  [ 79   1]]
#
#     -----METRICS FOR XGBoost------
#     ROC_AUC: 0.51
#     F1_SCORE: 0.10
#
#
#
# 	CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87       320
#            1       0.25      0.06      0.10        80
#
#     accuracy                           0.78       400
#    macro avg       0.53      0.51      0.49       400
# weighted avg       0.69      0.78      0.72       400
#
#
#
#
# CONFUSION MATRIX FOR XGBoost
# [[305  15]
#  [ 75   5]]

# %%
from sklearn.metrics import confusion_matrix

# %%
print(y_test.value_counts())
# Out:
# severe
# 0         320
# 1          80
# Name: count, dtype: int64
